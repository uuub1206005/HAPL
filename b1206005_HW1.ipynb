# %%
11print("I'm a student")
# Out:
# I'm a student

# %%
print("輸入A(x1，y1)")
x1 = float(input("x1="))
y1 = float(input("y1="))

print("輸入B(x2，y2)")
x2 = float(input("x2="))
y2 = float(input("y2="))

a = (x1-x2)**2+(y1-y2)**2
a**= 0.5


print("距離=",a)
# Out:
# 輸入A(x1，y1)
# x1=3
# y1=4
# 輸入B(x2，y2)
# x2=-2
# y2=16
# 距離= 13.0

# %%
w = float(input("體重(公斤)="))
h = float(input("身高(公尺)="))

w/=h**2

print("BMI=",w)
# Out:
# 體重(公斤)=52
# 身高(公尺)=1.55
# BMI= 21.64412070759625
